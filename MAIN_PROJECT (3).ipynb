# %% [markdown]
#  # Python module end assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('myexcel.xlsx')
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age               Height  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454     Raul Neto  Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455  Tibor Pleiss  Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456   Jeff Withey  Utah Jazz      24        C   26                  7-0
# 457      Priyanka  Utah Jazz      34        C   25  2023-03-07 00:00:00
#
#      Weight College     Salary
# 453     203  Butler  2433333.0
# 454     179     NaN   900000.0
# 455     256     NaN  2900000.0
# 456     231  Kansas   947276.0
# 457     231  Kansas   947276.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
 df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing:
# ### Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis.

# %%
import random

df['Height']=df['Height'].apply(lambda x:random.randint(150,180))
df['Height']
# Out:
# 0      170
# 1      160
# 2      180
# 3      160
# 4      171
#       ...
# 453    166
# 454    152
# 455    166
# 456    168
# 457    150
# Name: Height, Length: 458, dtype: int64

# %%
df.shape
# Out:
# (458, 9)

# %%
df.nunique()
# Out:
# Name        458
# Team         30
# Number       53
# Position      5
# Age          22
# Height       31
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %%
df.isnull().value_counts()
# Out:
# Name   Team   Number  Position  Age    Height  Weight  College  Salary
# False  False  False   False     False  False   False   False    False     365
#                                                        True     False      82
#                                                        False    True        9
#                                                        True     True        2
# Name: count, dtype: int64

# %%
df.fillna('0',inplace=True)
# Out:
# C:\Users\AP\AppData\Local\Temp\ipykernel_3956\529854845.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('0',inplace=True)

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %% [markdown]
# #count,unique,topfreq,mean,SD,min,25%,50%,75%,max these statistical measures are
# obtained in a simpleway,
# using describe method.

# %%
sns.boxplot(x='Position',y='Salary',data=df)
# Out:
# <Axes: xlabel='Position', ylabel='Salary'>

# %%
plt.figure(figsize=(20,7))
plt.xticks(rotation=45)
sns.boxplot(x='Team',y='Salary',data=df)
# Out:
# <Axes: xlabel='Team', ylabel='Salary'>

# %% [markdown]
# ### 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
df1=df.groupby('Team')['Name']
for i in df1:
    print(i)
# Out:
# ('Atlanta Hawks', 309       Kent Bazemore
# 310    Tim Hardaway Jr.
# 311        Kirk Hinrich
# 312          Al Horford
# 313      Kris Humphries
# 314         Kyle Korver
# 315        Paul Millsap
# 316        Mike Muscala
# 317     Lamar Patterson
# 318     Dennis Schroder
# 319          Mike Scott
# 320     Thabo Sefolosha
# 321      Tiago Splitter
# 322      Walter Tavares
# 323         Jeff Teague
# Name: Name, dtype: object)
# ('Boston Celtics', 0       Avery Bradley
# 1         Jae Crowder
# 2        John Holland
# 3         R.J. Hunter
# 4       Jonas Jerebko
# 5        Amir Johnson
# 6       Jordan Mickey
# 7        Kelly Olynyk
# 8        Terry Rozier
# 9        Marcus Smart
# 10    Jared Sullinger
# 11      Isaiah Thomas
# 12        Evan Turner
# 13        James Young
# 14       Tyler Zeller
# Name: Name, dtype: object)
# ('Brooklyn Nets', 15           Bojan Bogdanovic
# 16               Markel Brown
# 17            Wayne Ellington
# 18    Rondae Hollis-Jefferson
# ...

# %%
df1=df.groupby('Team')['Name'].apply(list)
for Team,Names in df1.items():
    print(f"The employees in {Team} are")
    for Name in Names:
        print(Name)
# Out:
# The employees in Atlanta Hawks are
# Kent Bazemore
# Tim Hardaway Jr.
# Kirk Hinrich
# Al Horford
# Kris Humphries
# Kyle Korver
# Paul Millsap
# Mike Muscala
# Lamar Patterson
# Dennis Schroder
# Mike Scott
# Thabo Sefolosha
# Tiago Splitter
# Walter Tavares
# Jeff Teague
# The employees in Boston Celtics are
# Avery Bradley
# Jae Crowder
# John Holland
# R.J. Hunter
# Jonas Jerebko
# Amir Johnson
# Jordan Mickey
# Kelly Olynyk
# Terry Rozier
# Marcus Smart
# Jared Sullinger
# Isaiah Thomas
# Evan Turner
# James Young
# Tyler Zeller
# The employees in Brooklyn Nets are
# Bojan Bogdanovic
# Markel Brown
# Wayne Ellington
# Rondae Hollis-Jefferson
# Jarrett Jack
# Sergey Karasev
# Sean Kilpatrick
# Shane Larkin
# Brook Lopez
# Chris McCullough
# Willie Reed
# Thomas Robinson
# Henry Sims
# Donald Sloan
# Thaddeus Young
# The employees in Charlotte Hornets are
# Nicolas Batum
# Troy Daniels
# Jorge Gutierrez
# Tyler Hansbrough
# Aaron Harrison
# Spencer Hawes
# Al Jefferson
# ...

# %%
from matplotlib.pyplot import figure
figure(num='None',figsize=(45,40),dpi=250)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Team",fontsize=30)
plt.ylabel("No.of employees",fontsize=30)
sns.countplot(x='Team',data=df,palette='viridis')
plt.show()
# Out:
# C:\Users\AP\AppData\Local\Temp\ipykernel_3956\640183194.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Team',data=df,palette='viridis')

# %% [markdown]
# #From this count plot we can understand that 'New Orleans Pelicans' is the team which has highest no.of employees.From this, number of employees in the team 'New Orleans Pelicans' has 18+ employees.
# The second most team which has highest no.of employees is 'Memphis Grizzlies'

# %%
team_count=df['Team'].value_counts()

team_count
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# #From the value_count we can get the no.of employees in each team.

# %%
len(df)
# Out:
# 458

# %% [markdown]
# #from this we have clear that there are 458 employees

# %% [markdown]
# ### Percentage split relative to the total no.of employees is

# %%
percentage=round((team_count/len(df))*100,2)
percentage
# Out:
# Team
# New Orleans Pelicans      4.15
# Memphis Grizzlies         3.93
# Utah Jazz                 3.49
# New York Knicks           3.49
# Milwaukee Bucks           3.49
# Brooklyn Nets             3.28
# Portland Trail Blazers    3.28
# Oklahoma City Thunder     3.28
# Denver Nuggets            3.28
# Washington Wizards        3.28
# Miami Heat                3.28
# Charlotte Hornets         3.28
# Atlanta Hawks             3.28
# San Antonio Spurs         3.28
# Houston Rockets           3.28
# Boston Celtics            3.28
# Indiana Pacers            3.28
# Detroit Pistons           3.28
# Cleveland Cavaliers       3.28
# Chicago Bulls             3.28
# Sacramento Kings          3.28
# Phoenix Suns              3.28
# Los Angeles Lakers        3.28
# Los Angeles Clippers      3.28
# Golden State Warriors     3.28
# Toronto Raptors           3.28
# Philadelphia 76ers        3.28
# Dallas Mavericks          3.28
# Orlando Magic             3.06
# Minnesota Timberwolves    3.06
# ...

# %%
labels=team_count.index
plt.figure(figsize=(20,7))
plt.pie(percentage,data=df,labels=labels,autopct='%.1f%%')
plt.title('Percentage split relative to the total no.of employees')
plt.show()

# %% [markdown]
# #From this pie plot it is easy to understand percentage split of each team relative to the total no.of employees.Here the team'New Orleans Pelicans' has highest percentage.
# The team 'Memphis Grizzlies' has second most highest percentage.
# The teams 'Orlando Magic and
# Minnesota Timberwolve' have the lowest percentages.

# %% [markdown]
# ### 2. Segregate employees based on their positions within the company.

# %%
sns.countplot(x='Position',data=df)
# Out:
# <Axes: xlabel='Position', ylabel='count'>

# %% [markdown]
# #From this countplot it is clear that
# the position SG has more no.of employees.
# C position has minimum no.of employees.

# %%
df2=df.groupby('Position')['Name'].apply(list)
for Position,Names in df2.items():
    print(f"\nEmployees in {Position} position\n")
    for Name in Names:
        print(Name)
# Out:
# Employees in C position
#
# Kelly Olynyk
# Jared Sullinger
# Tyler Zeller
# Brook Lopez
# Henry Sims
# Robin Lopez
# Kevin Seraphin
# Joel Embiid
# Jahlil Okafor
# Bismack Biyombo
# Lucas Nogueira
# Jonas Valanciunas
# Andrew Bogut
# Festus Ezeli
# Marreese Speights
# Cole Aldrich
# DeAndre Jordan
# Tarik Black
# Roy Hibbert
# Robert Sacre
# Tyson Chandler
# Alex Len
# Alan Williams
# Willie Cauley-Stein
# DeMarcus Cousins
# Kosta Koufos
# Pau Gasol
# Joakim Noah
# Sasha Kaun
# Timofey Mozgov
# Tristan Thompson
# Joel Anthony
# Aron Baynes
# Andre Drummond
# Jordan Hill
# Ian Mahinmi
# Greg Monroe
# Miles Plumlee
# JaVale McGee
# Salah Mejri
# Zaza Pachulia
# Dwight Howard
# Josh Smith
# Marc Gasol
# Alexis Ajinca
# Omer Asik
# Kendrick Perkins
# Matt Bonner
# Boris Diaw
# Tim Duncan
# Boban Marjanovic
# Al Horford
# Tiago Splitter
# Walter Tavares
# Al Jefferson
# Frank Kaminsky III
# Cody Zeller
# Hassan Whiteside
# Dewayne Dedmon
# Nikola Vucevic
# Marcin Gortat
# JJ Hickson
# ...

# %% [markdown]
# ### 3. Identify the predominant age group among employees.

# %%
#here we want to create a newcolumn for 'age group'.

# %%
df[df['Age']>40]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
df[df['Age']<20]
# Out:
#               Name             Team  Number Position  Age  Height  Weight  \
# 122   Devin Booker     Phoenix Suns       1       SG   19     165     206
# 226  Rashad Vaughn  Milwaukee Bucks      20       SG   19     161     202
#
#       College     Salary
# 122  Kentucky  2127840.0
# 226      UNLV  1733040.0

# %%
df['Age group']=df['Age'].apply(lambda x:'19-24' if x>=19 and x<=24 else('25-30' if x>=25 and x<=30 else ('31-35' if x>=31 and x<=35 else('36-40' if x>=36 and x<=40 else 'Null'))))
df['Age group']
# Out:
# 0      25-30
# 1      25-30
# 2      25-30
# 3      19-24
# 4      25-30
#        ...
# 453    25-30
# 454    19-24
# 455    25-30
# 456    25-30
# 457    25-30
# Name: Age group, Length: 458, dtype: object

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     170     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     160     235
# 2     John Holland  Boston Celtics      30       SG   27     180     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     160     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     171     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     166     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     166     256
# 456    Jeff Withey       Utah Jazz      24        C   26     168     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College     Salary Age group
# 0                Texas  7730337.0     25-30
# ...

# %%
df['Age'].isnull().value_counts()
# Out:
# Age
# False    458
# Name: count, dtype: int64

# %%
sns.countplot(x='Age group',data=df,palette='viridis')
# Out:
# C:\Users\AP\AppData\Local\Temp\ipykernel_3956\1694574464.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age group',data=df,palette='viridis')
# <Axes: xlabel='Age group', ylabel='count'>

# %% [markdown]
# #from this count plot of age group ,
# we can see 25-30 is the predominant age group.
# This means that majority of employees are under the age group 25-30.

# %%
a=df['Age group'].value_counts()
a
# Out:
# Age group
# 25-30    213
# 19-24    154
# 31-35     68
# 36-40     23
# Name: count, dtype: int64

# %%
a.idxmax()
# Out:
# '25-30'

# %% [markdown]
# #Hence it is clear that predominant age group is 25-30.
# 213 persons are under the age group 25-30

# %% [markdown]
# ### 4. Discover which team and position have the highest salary expenditure.

# %%
df['Salary'].isnull().value_counts()
# Out:
# Salary
# False    458
# Name: count, dtype: int64

# %%
df['Salary']
# Out:
# 0      7730337.0
# 1      6796117.0
# 2              0
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457     947276.0
# Name: Salary, Length: 458, dtype: object

# %%
df4=df.groupby(['Position','Team'])['Salary'].sum()
print(df4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[245], line 1
# ----> 1 df4=df.groupby(['Position','Team'])['Salary'].sum()
#       2 print(df4)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
#    3150             npfunc=np.sum,
#    3151         )
# ...

# %%
s=df4.reset_index(['Team'])
x=s.index
y=s.Salary
sns.boxplot(x=s.index,y=s.Salary,data=s)
# Out:
# <Axes: xlabel='Position', ylabel='Salary'>

# %% [markdown]
# #From this boxplot of position with salary,
# it is clear that the ' SF' position has the highest salary.

# %%
plt.figure(figsize=(20,8))
s=df4.reset_index(['Position'])
x=s.index
y=s.Salary
plt.xticks(rotation=45)
sns.boxplot(x=s.index,y=s.Salary,data=s)
# Out:
# <Axes: xlabel='Team', ylabel='Salary'>

# %%
#From this boxplot of Team with salary, it is clear that the ' Los Angeles Lakers' Team has the highest salary.

# %%
print(df4.idxmax())
# Out:
# ('SF', 'Los Angeles Lakers')

# %%
 #The Team 'Los Angeles Lakers' of position 'SF' have the highest salary expenditure

# %% [markdown]
# ### 5. Investigate if there's any correlation between age and salary, and represent it visually.

# %%
correlation=df['Age'].corr(df['Salary'])
print(correlation)
# Out:
# 0.2050096028480935

# %%
plt.title("Correlation b/n age and salary")
plt.xlabel("Salary")
plt.ylabel("Age")
x=df['Salary'].values
y=df['Age'].values
data=pd.DataFrame({'x':x,'y':y})
print(data)
sns.scatterplot(data=data,x='x',y='y')
plt.show()
# Out:
#              x   y
# 0    7730337.0  25
# 1    6796117.0  25
# 2            0  27
# 3    1148640.0  22
# 4    5000000.0  29
# ..         ...  ..
# 453  2433333.0  26
# 454   900000.0  24
# 455  2900000.0  26
# 456   947276.0  26
# 457   947276.0  25
#
# [458 rows x 2 columns]

# %% [markdown]
# #from this scatter plot of 'Age' with 'Salary' , correlation between age and salary are more clear.
# By calculation we get correlation is 0.205,
# from the graph also we can understand correlation is 0.20 something

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Salary')

# %%
sns.pairplot(df,hue='Position')

# %% [markdown]
# #This pair plot shows pairwise relationship between
# variables within the dataset

# %% [markdown]
# #By using this python it can express complex tasks by using a fewlines of code.
# This is open sourse and has extensive library support.This is easy to learn and flexible.
